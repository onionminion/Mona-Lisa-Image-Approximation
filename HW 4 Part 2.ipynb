# %% [markdown]
# # Random Forests for Image Approximation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import imageio.v3 as iio
import random

# %% [markdown]
# ## Part A

# %%
im = iio.imread('MonaLisa.jpeg')
print(im.shape)
plt.imshow(im)
# Out:
# (1526, 1024, 3)

# %% [markdown]
# ## Part B: Preprocessing Input

# %%
# Out:
# 1024
